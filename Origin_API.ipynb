# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
#from oauth2client.tools import argparser
import pandas as pd
import pprint 
import matplotlib.pyplot as md
from pprint import pprint 

DEVELOPER_KEY = "AIzaSyCD9C_oboRF0vUJUgQSl4dLyUqMsEWU25Q"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
def youtube_search(q, max_results=50,order="viewCount", token=None, location=None, location_radius=None):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)
    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet", # Part signifies the different types of data you want 
    maxResults=max_results,
    location=location,
    locationRadius=location_radius).execute()

    title = []
    channelId = []
    channelTitle = []
    categoryId = []
    videoId = []
    viewCount = []
    likeCount = []
    dislikeCount = []
    commentCount = []
    category = []
    tags = []
    videos = []

    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":
            title.append(search_result['snippet']['title']) 
            videoId.append(search_result['id']['videoId'])
            response = youtube.videos().list(
                part='statistics, snippet',
                id=search_result['id']['videoId']).execute()
            channelId.append(response['items'][0]['snippet']['channelId'])
            channelTitle.append(response['items'][0]['snippet']['channelTitle'])
            categoryId.append(response['items'][0]['snippet']['categoryId'])
            viewCount.append(response['items'][0]['statistics']['viewCount'])
            likeCount.append(response['items'][0]['statistics']['likeCount'])
            dislikeCount.append(response['items'][0]['statistics']['dislikeCount'])
        if 'commentCount' in response['items'][0]['statistics'].keys():
            commentCount.append(response['items'][0]['statistics']['commentCount'])
        else:
            commentCount.append([])
        if 'tags' in response['items'][0]['snippet'].keys():
            tags.append(response['items'][0]['snippet']['tags'])
        else:
            tags.append([])
    youtube_dict = {'tags':tags,'channelId': channelId,'channelTitle': channelTitle,'categoryId':categoryId,'title':title,'videoId':videoId,'viewCount':viewCount,'likeCount':likeCount,'dislikeCount':dislikeCount,'commentCount':commentCount}
    return youtube_dict

# %%
test = youtube_search('Sports', location='33.5186,-86.8104', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Birmingham_Alabama.csv', index=False, header=True)

test = youtube_search('Sports', location='61.2181,-149.9003', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Anchorage_Alaska.csv', index=False, header=True)

test = youtube_search('Sports', location='33.4484,-112.0740', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Phoenix_Arizona.csv', index=False, header=True)

test = youtube_search('Sports', location='34.7465,-92.2896', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Little_Rock_Arkansas.csv', index=False, header=True)

test = youtube_search('Sports', location='34.0522,-118.2437', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Los_Angeles_California.csv', index=False, header=True)

test = youtube_search('Sports', location='39.7392,-104.9903', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Denver_Colorado.csv', index=False, header=True)

test = youtube_search('Sports', location='41.1792,-73.1894', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Bridgeport_Connecticut.csv', index=False, header=True)

test = youtube_search('Sports', location='39.7447,-75.5484', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Wilmington_Delaware.csv', index=False, header=True)

test = youtube_search('Sports', location='30.3322,-81.6557', location_radius='100mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Jacksonville_Florida.csv', index=False, header=True)

test = youtube_search('Sports', location='33.7490,-84.3880', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Atlanta_Georgia.csv', index=False, header=True)

test = youtube_search('Sports', location='29.7604,-95.3698', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Honolulu_Hawaii.csv', index=False, header=True)

test = youtube_search('Sports', location='43.6150,-116.2023', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Boise_Idaho.csv', index=False, header=True)

test = youtube_search('Sports', location='41.8781,-87.6298', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Chicago_Illinois.csv', index=False, header=True)

test = youtube_search('Sports', location='39.7684,-86.1581', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Indianapolis_Indiana.csv', index=False, header=True)

test = youtube_search('Sports', location='41.5868,-93.6250', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Des_Moines_Iowa.csv', index=False, header=True)

test = youtube_search('Sports', location='37.6872,-97.3301', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Wichita_Kansas.csv', index=False, header=True)

test = youtube_search('Sports', location='38.2527,-85.7585', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Lousiville_Kentucky.csv', index=False, header=True)

test = youtube_search('Sports', location='29.9511,-90.0715', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/New_Orleans_Louisiana.csv', index=False, header=True)

test = youtube_search('Sports', location='43.6591,-70.2568', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Portland_Maine.csv', index=False, header=True)

test = youtube_search('Sports', location='39.2904,-76.6122', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Baltimore_Maryland.csv', index=False, header=True)

test = youtube_search('Sports', location='42.3601,-71.0589', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Boston_Massachusetts.csv', index=False, header=True)

test = youtube_search('Sports', location='42.3314,-83.0458', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Detroit_Michigan.csv', index=False, header=True)

test = youtube_search('Sports', location='44.9778,-93.2650', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Minneapolis_Minnesota.csv', index=False, header=True)

test = youtube_search('Sports', location='32.2988,-90.1848', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Jackson_Mississippi.csv', index=False, header=True)

test = youtube_search('Sports', location='39.0997,-94.5786', location_radius='75mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Kansas_City_Missouri.csv', index=False, header=True)

test = youtube_search('Sports', location='45.7833,-108.5007', location_radius='75mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Billings_Montana.csv', index=False, header=True)

test = youtube_search('Sports', location='41.2565,-95.9345', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Omaha_Nebraska.csv', index=False, header=True)

test = youtube_search('Sports', location='36.1699,-115.1398', location_radius='1000km')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Las_Vegas_Nevada.csv', index=False, header=True)

test = youtube_search('Sports', location='42.9956,-71.4548', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Manchester_New_Hampshire.csv', index=False, header=True)

test = youtube_search('Sports', location='40.7357,-74.1724', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Newark_New_Jersey.csv', index=False, header=True)

test = youtube_search('Sports', location='35.0844,-106.6504', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Albuquerque_New_Mexico.csv', index=False, header=True)

test = youtube_search('Sports', location='40.7128,-74.0060', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/New_York_City_New_York.csv', index=False, header=True)

test = youtube_search('Sports', location='35.2271,-80.8431', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Charlotte_North_Carolina.csv', index=False, header=True)

test = youtube_search('Sports', location='46.8772,-96.7898', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Fargo_North_Dakota.csv', index=False, header=True)

test = youtube_search('Sports', location='39.9612,-82.9988', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Columbus_Ohio.csv', index=False, header=True)

test = youtube_search('Sports', location='35.4676,-97.5164', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Oklahoma_City_Oklahoma.csv', index=False, header=True)

test = youtube_search('Sports', location='45.5122,-122.6587', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Portland_Oregon.csv', index=False, header=True)

test = youtube_search('Sports', location='39.9526,-75.1652', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Philadelphia_Pennsylvania.csv', index=False, header=True)

test = youtube_search('Sports', location='41.8240,-71.4128', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Providence_Rhode_Island.csv', index=False, header=True)

test = youtube_search('Sports', location='34.0007,-81.0348', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Columbia_South_Carolina.csv', index=False, header=True)

test = youtube_search('Sports', location='43.5473,-96.7283', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Sioux_Falls_South_Dakota.csv', index=False, header=True)

test = youtube_search('Sports', location='35.1495,-90.0490', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Memphis_Tennessee.csv', index=False, header=True)

test = youtube_search('Sports', location='39.7604,-95.3698', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Houston_Texas.csv', index=False, header=True)

test = youtube_search('Sports', location='40.7608,-111.8910', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Salt_Lake_City_Utah.csv', index=False, header=True)

test = youtube_search('Sports', location='44.4759,-73.2121', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Burlington_Vermont.csv', index=False, header=True)

test = youtube_search('Sports', location='36.8529,-75.9780', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Viriginia_Beach_Virginia.csv', index=False, header=True)

test = youtube_search('Sports', location='47.6062,-122.3321', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Seattle_Washington.csv', index=False, header=True)

test = youtube_search('Sports', location='38.3498,-81.6326', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Charleston_West_Virginia.csv', index=False, header=True)

test = youtube_search('Sports', location='43.0389,-87.9065', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Milwaukee_Wisconsin.csv', index=False, header=True)

test = youtube_search('Sports', location='41.1400,-104.8202', location_radius='200mi')
all_data = pd.DataFrame(test)
all_data.to_csv('Datasets/Cheyenne_Wyoming.csv', index=False, header=True)
